# %% [markdown]
# <a href="https://colab.research.google.com/github/Manu-Gr/Python/blob/main/Python_Intro_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns

# %%
df=pd.read_csv("/content/Salaries.csv")

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10)   #for displaying first 10 records
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.head(20)   #for displaying first 20 records
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df.head(50)   #for displaying first 50 records
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
train = pd.read_csv("/content/train.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# # Data Frame Attributes

# %%
df.dtypes   #To find type of datatypes we have in given DB
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns # to find the columns present
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.ndim # number of dimension
# Out:
# 2

# %%
df.size #total size of DB i.e no of rows x columns
# Out:
# 468

# %%
df.shape #the no of rows and no of columns , 1st one is row and 2nd one columns
# Out:
# (78, 6)

# %%
df.values #to fetch all the values

# %% [markdown]
# # Data Frames Methods

# %%
df.std() #To get standard deviation of all the columns
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.describe() # TO get the summary of the dataset
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#TO get mean values of first 50 data

#Method 1

df_50=df.head(50)
df_50.mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
# Method 2

df.head(50).mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %% [markdown]
# ### Selecting column in dataframe

# %%
df['rank'] #method 1
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df[['rank']] #Method 2 -- this is prefered as we can we can see the data in structed format
# Out:
#          rank
# 0        Prof
# 1        Prof
# 2        Prof
# 3        Prof
# 4        Prof
# ..        ...
# 73       Prof
# 74  AssocProf
# 75       Prof
# 76       Prof
# 77       Prof
#
# [78 rows x 1 columns]

# %%
df.phd.describe()  #Calculate basic statistics for phd column
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.count() #COunt the number of columns in phd column
# Out:
# 78

# %%
df.phd.mean() #Calculate the average value in phd column
# Out:
# 19.705128205128204

# %% [markdown]
# ### Data Frames Groupby Method

# %%
df_rank=df.groupby(['rank'])
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %% [markdown]
# #### Data Frame : Filtering

# %%
df[df['salary']>120000]  #Calculate salry for each professor salry > 120000

# %%
df[df['sex']=='Female']  # Select only those rows that contain female professor

# %%
# Select Female whose service is greater than 10 yrs

#Method 1

#Step 1

df.sex=='Female' # this gets the female but is in boolean form
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73     True
# 74     True
# 75     True
# 76     True
# 77     True
# Name: sex, Length: 78, dtype: bool

# %%
df.service>10 # This gets the service >10yrs and also in boolean form
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
#       ...
# 73    False
# 74    False
# 75     True
# 76     True
# 77     True
# Name: service, Length: 78, dtype: bool

# %%
# now we have to combine both of the above conditions

df[(df.sex=='Female') & (df.service>10)]
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 51       Prof          B   20       14  Female  127512
# 54  AssocProf          A   25       22  Female   62884
# 58       Prof          B   36       26  Female  144651
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 67       Prof          A   17       11  Female   90450
# 72       Prof          B   24       15  Female  161101
# 75       Prof          B   17       17  Female  124312
# ...

# %%
# Method 2

df_f=df[(df.sex=='Female')]
df_f
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
df_f[df_f.service>10]
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 51       Prof          B   20       14  Female  127512
# 54  AssocProf          A   25       22  Female   62884
# 58       Prof          B   36       26  Female  144651
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 67       Prof          A   17       11  Female   90450
# 72       Prof          B   24       15  Female  161101
# 75       Prof          B   17       17  Female  124312
# ...
